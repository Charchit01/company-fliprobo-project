# %%
! pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\rrd\anaconda\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\rrd\anaconda\lib\site-packages (from selenium) (1.25.9)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import urllib.request
import math
import time
from pandas import DataFrame, Series
from urllib.request import Request, urlopen
import requests
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import chrome
from selenium.common.exceptions import *

# %%
jobs={"roles":[],
     "companies":[],
     "locations":[],
     "experience":[],
     "skills":[],
     "Dates":[],
     "salary":[],}

# %%
MAX_PAGE_NUM = 50
MAX_PAGE_DIG = 3

# %%
driver = webdriver.Edge(r"C:\Users\rrd\Desktop\doubt\msedgedriver.exe")

# %%
for i in range(1, MAX_PAGE_NUM+1):
    page_num = (MAX_PAGE_DIG - len(str(i))) * "0" + str(i)
    url="https://www.naukri.com/data-scientist-jobs-"+page_num+"?k=data%20scientist"
    driver.get(url)
    time.sleep(3)
    lst=driver.find_elements_by_css_selector(".jobTuple.bgWhite.br4.mb-8")
    
    for job in lst:
        driver.implicitly_wait(10)
        try:
            role=job.find_element_by_css_selector("a.title.fw500.ellipsis").text
            company=job.find_element_by_css_selector("a.subTitle.ellipsis.fleft").text
            location=job.find_element_by_css_selector(".fleft.grey-text.br2.placeHolderLi.location").text
            salaries=job.find_element_by_css_selector(".fleft.grey-text.br2.placeHolderLi.salary").text
            exp=job.find_element_by_css_selector(".fleft.grey-text.br2.placeHolderLi.experience").text
            date=job.find_element_by_css_selector(".type.br2.fleft.grey").text
            skills=job.find_element_by_css_selector(".tags.has-description").text 
        except NoSuchElementException:
             pass
        jobs["roles"].append(role)
        jobs["companies"].append(company)
        jobs["locations"].append(location)
        jobs["experience"].append(exp)
        jobs["salary"].append(salaries)
        jobs["Dates"].append(date)
        jobs["skills"].append(skills)

# %%
df1=pd.DataFrame(jobs)
df1
# Out:
#                                                  roles  \
# 0                                       Data Scientist
# 1                                 Staff Data Scientist
# 2    Opportunity For Data Scientist Internship - Be...
# 3                    Data Scientist - Machine Learning
# 4       Data Scientist || Data Analyst || Data science
# ..                                                 ...
# 995                                     Data Scientist
# 996                                     Data Scientist
# 997                    Senior Data & Applied Scientist
# 998                                     Data Scientist
# 999                                     Data Scientist
#
#                                       companies  \
# 0         CronJ IT Technologies Private Limited
# 1                     Walmart Global Tech India
# 2                        Corner Stone Solutions
# 3                                   AugmatrixGo
# 4    Inspiration Manpower Consultancy Pvt. Ltd.
# ..                                          ...
# 995                             ExecBoardinAsia
# 996                    Ganit Business Solutions
# 997                       Microsoft Corporation
# 998                         Fetch Rewards, Inc.
# 999                Gauge Data Solutions Pvt Ltd
#
#                             locations experience  \
# 0                 Bangalore/Bengaluru    0-1 Yrs
# 1                               Other    0-5 Yrs
# 2                 Bangalore/Bengaluru    0-1 Yrs
# 3                 Bangalore/Bengaluru    2-5 Yrs
# 4    Navi Mumbai, Bangalore/Bengaluru   6-11 Yrs
# ..                                ...        ...
# 995                           Chennai  11-15 Yrs
# 996                           Chennai    2-7 Yrs
# 997               Bangalore/Bengaluru   7-12 Yrs
# 998                            remote    1-6 Yrs
# 999                             Noida    2-5 Yrs
#
#                                                 skills         Dates  \
# 0    IT Skills\nPython\nData Science\nAWS\nTensorfl...    8 DAYS AGO
# 1                                                   NA    6 DAYS AGO
# 2    NLP\nOpencv\nArtificial Intelligence\nData Sci...   15 DAYS AGO
# 3    Hive\nR\nCloud Computing\nData Scientist\nComp...    7 DAYS AGO
# 4    Data Science\nJava\nR\nEDA\nStatistical Modeli...   14 DAYS AGO
# ..                                                 ...           ...
# 995      data science\nBanking\nPresales\nIT marketing  30+ DAYS AGO
# 996                                          Analytics  30+ DAYS AGO
# 997  Computer science\nCloud computing\nC++\nProtot...  30+ DAYS AGO
# 998  IT Skills\nPython\nSoftware Development\nData ...  30+ DAYS AGO
# 999  IT Skills\nJava\nPython\nMachine Learning\nArt...  30+ DAYS AGO
#
#                         salary
# 0      3,50,000 - 5,00,000 PA.
# 1                Not disclosed
# 2      1,00,000 - 3,00,000 PA.
# 3                Not disclosed
# 4    14,00,000 - 22,50,000 PA.
# ..                         ...
# 995              Not disclosed
# 996              Not disclosed
# 997              Not disclosed
# 998              Not disclosed
# 999              Not disclosed
#
# [1000 rows x 7 columns]

# %%
df1.to_csv("naukriscrapdata.csv")

# %%
df1.columns
# Out:
# Index(['roles', 'companies', 'locations', 'experience', 'skills', 'Dates',
#        'salary'],
#       dtype='object')
